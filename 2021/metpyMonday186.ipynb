# %% [markdown]
# ## 186 - National LCL Map Part 1
#
# [Youtube](https://www.youtube.com/watch?v=Kayf2ZYGWM4)

# %%
from datetime import datetime
from metpy.units import units
from siphon.simplewebservice.iastate import IAStateUpperAir
import pandas as pd

# %%
date = datetime(2021, 6, 13, 0)

# %%
df = IAStateUpperAir.request_all_data(date)

# %%
df.head()
# Out:
#    pressure  height  temperature  dewpoint  direction  speed station  \
# 0     963.0   386.0         19.4      14.4      265.0    8.0    CWPL
# 1     957.0   439.0         18.6      12.6        NaN    NaN    CWPL
# 2     951.0   493.0         18.0      13.0        NaN    NaN    CWPL
# 3     938.2   609.0          NaN       NaN      270.0   11.0    CWPL
# 4     925.0   730.0         16.0      11.2      280.0   20.0    CWPL
#
#         time     u_wind        v_wind
# 0 2021-06-13   7.969558  6.972459e-01
# 1 2021-06-13        NaN           NaN
# 2 2021-06-13        NaN           NaN
# 3 2021-06-13  11.000000  2.020667e-15
# 4 2021-06-13  19.696155 -3.472964e+00

# %%
df.tail()
# Out:
#        pressure   height  temperature  dewpoint  direction  speed station  \
# 14578       7.5  33528.0          NaN       NaN       75.0   32.0    KYMW
# 14579       7.0  34030.0        -30.3     -64.3      115.0   24.0    KYMW
# 14580       6.4  34667.0        -29.5     -63.5        NaN    NaN    KYMW
# 14581       6.2  34893.0        -30.1     -64.1        NaN    NaN    KYMW
# 14582       6.1  35052.0          NaN       NaN      130.0   16.0    KYMW
#
#             time     u_wind     v_wind
# 14578 2021-06-13 -30.909626  -8.282209
# 14579 2021-06-13 -21.751387  10.142838
# 14580 2021-06-13        NaN        NaN
# 14581 2021-06-13        NaN        NaN
# 14582 2021-06-13 -12.256711  10.284602

# %%
# ruc.noaa.gov/raobs/stat2000.txt
stations = df['station'].unique()
stations
len(stations)
# Out:
# 113

# %%
df_locations = pd.read_csv('https://ruc.noaa.gov/raobs/stat2000.txt', delim_whitespace = True, skiprows = 1, usecols = [0, 3, 4], names = ['station', 'lat', 'lon'])
df_locations.head()
# Out:
#   station    lat     lon
# 0     NPC  14.05   83.57
# 1     EPZ  31.90  106.70
# 2     DRA  36.93  116.07
# 3     DRA  36.60  115.97
# 4     DRA  36.95  116.05

# %%
stations_with_location = []
for s in stations:
 stn_id = s[1:]
 if stn_id in df_locations['station'].values:
  stations_with_location.append(s)
 else:
  print(f'No location for station {stn_id}')
# Out:
# No location for station SYA

# %%
len(stations_with_location)
# Out:
# 112

# %%
import metpy.calc as mpcalc
import numpy as np

# %%
stations = []
lats = []
lons = []
lcl_pressures = []
lcl_temperatures = []

for s in stations_with_location:
 data = df[df['station'] == s]
 idx = data['pressure'].idxmax()
 sfc_temp = data['temperature'][idx] * units.degC
 sfc_dewp = data['dewpoint'][idx] * units.degC
 sfc_pres = data['pressure'][idx] * units.hPa

 try:
  lcl_pres, lcl_temp = mpcalc.lcl(sfc_pres, sfc_temp, sfc_dewp)
  stn_id = s[1:]
  _, lat, lon = df_locations[df_locations['station'] == stn_id].values[0]
  stations.append(s)
  lats.append(lat)
  lons.append(-lon)
  lcl_pressures.append(lcl_pres.m)
  lcl_temperatures.append(lcl_temp.m)

 except RuntimeError:
  print(f'Failure for station {s}')

# %%
lcl_pressures
# Out:
# [894.0626154778957,
#  971.7486896258741,
#  694.5165827343895,
#  766.0618153521041,
#  897.5772434870901,
#  969.1801395036003,
#  959.9884144806176,
#  928.9048599411018,
#  990.2413101866263,
#  830.2225970894655,
#  937.2088389319623,
#  865.2393638880005,
#  979.9260033563219,
#  797.6059264662163,
#  982.0436615442642,
#  891.578234249826,
#  970.2116889403305,
#  877.4588969005625,
#  890.7514821082319,
#  930.9137622305353,
#  974.6931656620411,
#  762.2582564634531,
#  799.4536458397013,
#  495.67445153339537,
#  690.9145156345429,
#  923.1409817716286,
#  949.4932258233497,
#  824.6865376821679,
#  771.6710094228098,
#  799.8417998513153,
#  952.3546174004624,
#  890.8951170630455,
#  921.1421254790943,
#  661.4744166498241,
#  935.4394572672655,
#  830.6781319066432,
#  662.1398395137596,
#  900.603241169931,
#  1005.9763318438655,
#  778.0172085077728,
#  697.8948242654122,
#  1007.3835221085465,
#  899.8575749792543,
#  722.2646645548077,
#  nan,
#  nan,
#  889.5166683504603,
#  746.7831237746218,
#  474.2376979019505,
#  913.4213728998926,
#  830.5594495576202,
#  899.8916393401836,
#  427.0021860824173,
#  856.1074980829698,
#  645.3073791875944,
#  452.05250608856574,
#  758.153014834638,
#  915.8680082883099,
#  869.4747369007739,
#  929.0494897829585,
#  816.4879585178894,
#  854.8952426848376,
#  nan,
#  905.3402929361768,
#  840.9723225279589,
#  939.8498222069277,
#  959.4138984057736,
#  700.1447314146219,
#  686.1026398823618,
#  913.76679257979,
#  516.3199184326512,
#  883.2125263601608,
#  646.2698423174852,
#  871.5735816915989,
#  685.2551993136804,
#  940.758283209538,
#  773.5225832876243,
#  967.837230098665,
#  688.2828304652712,
#  749.5275925710815,
#  908.9902621463392,
#  833.7586727752692,
#  927.9226121186203,
#  706.4592955701847,
#  969.194735821927,
#  981.5986744305128,
#  723.4294500686403,
#  982.537588041655,
#  848.7057563005562,
#  560.4059562047483,
#  494.3485837074747,
#  nan,
#  874.6546458823623,
#  918.1436755223768,
#  899.7124367770822,
#  535.9436914001749,
#  853.8763715893498,
#  998.1796344995994,
#  912.4744709133919,
#  659.6097924738689,
#  981.1018273177049,
#  825.3849460061459,
#  467.0167017830034,
#  906.1456668789699,
#  622.2924002633484,
#  975.9411918534909,
#  475.24523119720965,
#  951.0181599157933,
#  961.4540102294667,
#  1006.0438596493368,
#  924.3118680092288,
#  827.0256914646675]
