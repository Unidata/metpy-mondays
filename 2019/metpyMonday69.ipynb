# %% [markdown]
# ## 69 - Declarative Plotting
#
# [Youtube](https://www.youtube.com/watch?v=mbxE2ovXx9M)

# %%
import xarray as xr
from metpy.cbook import get_test_data
from metpy.io import GiniFile
from metpy.plots import ImagePlot, MapPanel, PanelContainer

# %%
data = xr.open_dataset(GiniFile(get_test_data('NHEM-MULTICOMP_1km_IR_20151208_2100.gini')))
# Out:
# Adjusting bad PDB size from 0 to 512.

# %%
img = ImagePlot()
img.data = data
img.field = 'IR'
img.colormap = 'Greys_r'

# %%
panel = MapPanel()
panel.plots = [img]

# %%
pc = PanelContainer()
pc.panels = [panel]
pc.show()
# Out:
# /home/jessica/anaconda3/lib/python3.9/site-packages/cartopy/io/__init__.py:260: DownloadWarning: Downloading: https://naciscdn.org/naturalearth/110m/physical/ne_110m_coastline.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)
