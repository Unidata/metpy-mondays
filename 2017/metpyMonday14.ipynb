# %% [markdown]
# ## 14 - Adding a logo and timestamp
#
# [Youtube](https://www.youtube.com/watch?v=3sWdjJ2Rnks)

# %%
import matplotlib.pyplot as plt
import numpy as np
from metpy import plots

# %matplotlib inline

# %%
x = np.arange(100)
y = np.random.random(100)

# %%
fig = plt.figure(figsize = (10, 8))
ax = fig.add_subplot(1, 1, 1)
ax.scatter(x, y, color = 'red')

# %%
plots.add_metpy_logo(fig, x = 30)
fig

# %%
plots.add_unidata_logo(fig, x = 420, size = 'large')
fig

# %%
plots.add_timestamp(ax, y = 1.01)
fig
